# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/sales_data.csv', encoding ="latin1")
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107             30.0      95.70                2  2871.00
# 1        10121             34.0      81.35                5  2765.90
# 2        10134             41.0      94.74                2  3884.34
# 3        10145             45.0      83.26                6  3746.70
# 4        10159              NaN       0.00               14  5205.27
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0    2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05/07/2003 00:00  Shipped       2         5     2003  ...
# 2  07/01/2003 00:00  Shipped       3         7     2003  ...
# 3    8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 00:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        2
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df1 = df.fillna("")
df1.head(5)
# Out:
#    ORDERNUMBER QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107            30.0      95.70                2  2871.00
# 1        10121            34.0      81.35                5  2765.90
# 2        10134            41.0      94.74                2  3884.34
# 3        10145            45.0      83.26                6  3746.70
# 4        10159                       0.00               14  5205.27
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0    2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05/07/2003 00:00  Shipped       2         5     2003  ...
# 2  07/01/2003 00:00  Shipped       3         7     2003  ...
# 3    8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 00:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue                          NYC    NY
# ...

# %%
df1 = df[['COUNTRY', 'SALES','QUANTITYORDERED']]
df1.head()
# Out:
#   COUNTRY    SALES  QUANTITYORDERED
# 0     USA  2871.00             30.0
# 1  France  2765.90             34.0
# 2  France  3884.34             41.0
# 3     USA  3746.70             45.0
# 4     USA  5205.27              NaN

# %%
df1['UNITS SOLD'] = df['SALES'] / df['QUANTITYORDERED']
df1[['UNITS SOLD']].tail()
# Out:
#       UNITS SOLD
# 2818      112.22
# 2819      137.19
# 2820      125.99
# 2821       62.24
# 2822       65.52

# %%
df_group.groupby(['TERRITORY']).sum().sort_values('UNITS SOLD', ascending=True)
# Out:
#              UNITS SOLD
# TERRITORY
# Japan      1.259775e+04
# APAC       2.219729e+04
#            1.090040e+05
# EMEA                inf

# %%
df_group.plot(kind= "barh",color= "blue")
# Out:
# <Axes: >
